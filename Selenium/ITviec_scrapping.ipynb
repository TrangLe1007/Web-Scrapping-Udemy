# %%
import requests
from bs4 import BeautifulSoup as bs
from datetime import date
import pandas as pd

# %%
lst_salary=[]
lst_title=[]
lst_link=[]
lst_address=[]
lst_company_link=[]
url="https://itviec.com/it-jobs?page=1&source=search_job"

while True:
    session = "N5MRJF8QM5vIMavTZjGpVNwUEvNY3dC22JpgT%2F2xZOeiOJCcA2TwglX3iL66LRWFrTiaKNaMkK%2BfCdTLeAVP765d5SQEZn4PZf5e8y9Y%2Ba2iFMQoW%2Bj8un7aPr3FnqC13FKT%2Bm6yJ7xOd%2B48prHIfxq9kVs1P1C7ZM%2BUb8uq8%2FHguSqbvGQEEEeTdT6d63RxrWemo98Mvz5WNlC9%2FGOZQkFCOJCh9L6JEUe9SNYr6v6ThBAKvfMU1YzePVcD89FuLsrdtUHW8D3A532PYM74ZRZgq65dd0PqqBI5Yyk76FvU9wKGDIDOwJvhwfNIKmprxSySxV7bvM2CffzuMvW9dqDOJEV9Wh3v%2BOdq4ps3gt9drOVpdAkALe3sFVu5xqq64FNWtPjk6VJg4irdqC36YMmXGvvZoejb%2FuzB3O0PN%2FUPj2rlezHX%2BVPvDzay7zi1v2g6ghE5RmZlo0c1jjvALq1HYpQnTJt3Lo00c%2BEp0XI3TtrD2aYwHPi7GvEKF8CjjO88k10hE10LW8taHe6epE1KzKSYUNwi9WuQ61VPPbWQWMtkRg6H8CHs6w%3D%3D--m%2BHtTKnc9d%2Fcwldl--9isWji1wkVTPrwhzOL9DhA%3D%3D; path=/; HttpOnly; SameSite=Lax"   
    response = requests.get(url,cookies={'_ITViec_session': session})
    data=response.text
    soup=bs(data,"html.parser")
    salary=soup.findAll("div",{"class":"svg-icon__text"})
    for i in salary:
        lst_salary.append(i.text)
    box=soup.findAll("h2",{"class":"title"})
    for j in box:
        link=j.find("a").get("href")
        lst_link.append(link)
        title=j.find("a").text
        lst_title.append(title)
    address=soup.findAll("span",{"class":"text"})
    for f in address:
        lst_address.append(f.text)
    link_company=soup.findAll("div",{"class":"logo-wrapper"})
    for k in link_company:
        link_lst=k.find("a").get("href")
        lst_company_link.append(link_lst)

    url_tag=soup.find('a',{'rel':'next'})
    if url_tag["href"]: 
        url="https://itviec.com/"+ url_tag["href"]
        # print(url)
    else:
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-0e13c71ef31a> in <module>
#      31
#      32     url_tag=soup.find('a',{'rel':'next'})
# ---> 33     if url_tag["href"]:
#      34         url="https://itviec.com/"+ url_tag["href"]
#      35         # print(url)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
database = {'Title_job': lst_title,
            'Job_link':lst_link,
            'Company_link':lst_company_link,
            'Address':lst_address,
            'Salary':lst_salary         
            }
df = pd.DataFrame.from_dict(database, orient='index')

df = df.transpose()

df['date'] = pd.to_datetime('today').strftime("%m/%d/%Y")
df.to_csv('IT_job_Database.csv',encoding='utf-8-sig')
df.head(17)
# Out:
#                                   Title_job  \
# 0        5 NodeJS Developers/ReactJS/ VueJS
# 1              Java Developer (Spring, AWS)
# 2      Jr. Mobile Developer (Swift, Kotlin)
# 3                    Senior Java Developer
# 4                  Senior Oracle Developer
# 5             Omni-channel Technical leader
# 6      Product Quality Assurance Specialist
# 7   PHP Developer (Laravel) | Sign-on Bonus
# 8                 Senior Tester (QA QC/Web)
# 9      Application Developer (JAVA, Oracle)
# 10         Mid/Senior Web Frontend Engineer
# 11                        Automation Tester
# 12     Senior Java Engineer - Up to $3000++
# 13                       Senior QA Engineer
# 14       Frontend Dev (JavaScript, ReactJS)
# 15   Data Engineer (Python/NodeJS/Java)~40M
# 16      Solution Architect/Presales Manager
#
#                                              Job_link  \
# 0   /it-jobs/5-nodejs-developers-reactjs-vuejs-hdw...
# 1     /it-jobs/java-developer-spring-aws-incepit-1739
# 2   /it-jobs/jr-mobile-developer-swift-kotlin-go2j...
# 3   /it-jobs/senior-java-developer-home-credit-vie...
# 4   /it-jobs/senior-oracle-developer-home-credit-v...
# 5   /it-jobs/omni-channel-technical-leader-central...
# 6   /it-jobs/product-quality-assurance-specialist-...
# 7   /it-jobs/php-developer-laravel-sign-on-bonus-t...
# 8   /it-jobs/senior-tester-qa-qc-web-b2be-gss-viet...
# 9   /it-jobs/application-developer-java-oracle-vie...
# 10  /it-jobs/web-frontend-engineer-reactjs-vuejs-b...
# 11  /it-jobs/software-tester-vietnam-international...
# 12  /it-jobs/senior-java-engineer-up-to-3000-line-...
# 13      /it-jobs/senior-qa-engineer-line-vietnam-2022
# 14  /it-jobs/frontend-dev-javascpit-nodejs-reactj-...
# 15  /it-jobs/data-engineer-python-nodejs-java-40m-...
# 16  /it-jobs/solution-architect-presale-manager-hi...
#
#                                  Company_link      Address  \
# 0                        /companies/hdwebsoft  Ho Chi Minh
# 1                          /companies/incepit  Ho Chi Minh
# 2                           /companies/go2joy  Ho Chi Minh
# 3              /companies/home-credit-vietnam  Ho Chi Minh
# 4              /companies/home-credit-vietnam  Ho Chi Minh
# 5                   /companies/central-retail  Ho Chi Minh
# 6                            /companies/peeba  Ho Chi Minh
# 7     /companies/titan-technology-corporation  Ho Chi Minh
# 8                 /companies/b2be-gss-vietnam  Ho Chi Minh
# 9   /companies/vietnam-international-bank-vib       Ha Noi
# 10       /companies/baemin-vietnam-woowa-bros  Ho Chi Minh
# 11  /companies/vietnam-international-bank-vib       Ha Noi
# 12                  /companies/line-vietnam-2  Ho Chi Minh
# 13                  /companies/line-vietnam-2  Ho Chi Minh
# 14                  /companies/missing-corner       Ha Noi
# 15                          /companies/knorex  Ho Chi Minh
# 16                 /companies/hitachi-vantara  Ho Chi Minh
#
#                 Salary        date
# 0   Attractive salary   08/12/2021
# 1    1,200 - 2,000 USD  08/12/2021
# 2       You'll love it  08/12/2021
# 3       You'll love it  08/12/2021
# 4       You'll love it  08/12/2021
# 5    1,500 - 3,000 USD  08/12/2021
# 6       You'll love it  08/12/2021
# 7       You'll love it  08/12/2021
# 8    1,000 - 1,500 USD  08/12/2021
# 9           Competitve  08/12/2021
# 10      You'll love it  08/12/2021
# 11         Competitive  08/12/2021
# 12      You'll love it  08/12/2021
# 13      You'll love it  08/12/2021
# 14   1,200 - 2,000 USD  08/12/2021
# 15     700 - 2,000 USD  08/12/2021
# 16      You'll love it  08/12/2021
