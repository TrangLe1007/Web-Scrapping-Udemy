# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

cookies = {
    '__utmc': '136564663',
    '__utmz': '136564663.1628742969.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none)',
    '_hjid': '6eaa99e8-dae1-4e5e-bda1-89b286b0ced7',
    '_gid': 'GA1.2.894493281.1628742971',
    '_gcl_au': '1.1.979099550.1628742971',
    '__utma': '136564663.907883416.1628742969.1628742969.1628749030.2',
    '_hjAbsoluteSessionInProgress': '1',
    '__utmv': '136564663.|1=Job%20Detail%20Display=VB=1^5=My%20Job%20Alert%20Display=VB=1',
    '__zi': '3000.SSZzejyD3jSkdkMgrmuFn2YQfBlJ40EBPOVgjSjJNvblcFZtsKLDbZ6J-hYHGaYHDfsnl9H839SpcBYpbai8dm.1',
    'fpestid': 'FZY7A4mXr6OuOVQjKs4yuaU2FBR2Gvm-Gbr3wZN3GU6iGSUMDg9MqZEzU4IIqI_CcC6KIA',
    '__utmt': '1',
    '_gat_UA-103236-1': '1',
    '__utmb': '136564663.20.8.1628752911745',
    'XSRF-TOKEN': 'eyJpdiI6Im5uckVzOTJpMW1hTlQzVVg3b0M4akE9PSIsInZhbHVlIjoiMWFGb1Yza0w2Z1FkamxxaUVNTjZaaGoxNUNpeW9ETSs0ZlRub2lNYnoyOUZ6dHh2bmtsbUVVMmpiZDZzMEc4SSIsIm1hYyI6IjU4NWY2YTc4ZmE0ZGRhOWVhZWM5ZTlmMWMwOTY4ODg1NDY2Y2IzNjY2ZWQ2Mzc3NDJhOGNlMDczODdjMjM5OWQifQ%3D%3D',
    'securevietnamworkscom_session': 'eyJpdiI6InN4enpiOElUMm5QTEZla2tvS2NmRHc9PSIsInZhbHVlIjoidThKRHI5aitKRVhpVnZlYUtOUE55VFdkTWhzQjNYdjI1aWtUMHp6eUVORlNoZ2c3QjVQZEREcmtPelBKXC93TGciLCJtYWMiOiIwYzJlZDZiMDVkODIxZGNiYTRjNTUyOTk1NmFjMmI3ODI1N2VjZDUzNGY1M2Q3M2EzYTliMThkMDRiNWM1MzVjIn0%3D',
    'LANG_CODE': 'eyJpdiI6IldQWTNJdTdRc0FSSGxhUFF4RFVBUXc9PSIsInZhbHVlIjoidEVXdGhiXC9GVmFmTXJzTlFnclRRQ0E9PSIsIm1hYyI6IjhhNmZjNDkyNzYzYmNjZGUyZTBjMTFmZjMzZDVhYjhiOTI1OWQ1YWE2N2NhZjc3OWM4OTYyY2JhYjZlYTNjYTQifQ%3D%3D',
    '_ga_0GGBQ5L5MF': 'GS1.1.1628749032.2.1.1628753974.0',
    '_ga': 'GA1.2.907883416.1628742969',
}

headers = {
    'Connection': 'keep-alive',
    'Cache-Control': 'max-age=0',
    'sec-ch-ua': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"',
    'sec-ch-ua-mobile': '?0',
    'Upgrade-Insecure-Requests': '1',
    'Origin': 'https://secure.vietnamworks.com',
    'Content-Type': 'application/x-www-form-urlencoded',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-User': '?1',
    'Sec-Fetch-Dest': 'document',
    'Referer': 'https://secure.vietnamworks.com/login/en?client_id=3',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8',
}

params = (
    ('client_id', '3'),
)

data = {
  '_token': 'D1qT7i5ph7Mj6oWUt56LJ7A3zuC0IIipv0Ca1wre',
  'username': 'letrang.veo@gmail.com',
  'password': 'Letrang1007'
}
url='https://secure.vietnamworks.com/login/en'
s = requests.Session()

s.post(url, headers=headers, params=params, cookies=cookies, data=data)
response = s.get("https://www.vietnamworks.com/it-software-jobs-i35-en")
data=response.content
soup=bs(data,"html.parser")
search=soup.findAll("div",{"class":"location"})
len(search)
# Out:
# 0

# %%
search=soup.find_all("div",{"class":"job-info-wrapper"})
print(search)
# Out:
# []

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import time
from bs4 import BeautifulSoup as bs

driver = webdriver.Chrome(executable_path=r'D:\Platform\chromedriver_win32\chromedriver.exe')#PUT YOUR CHROMEDRIVER PATH HERE

driver.get("https://secure.vietnamworks.com/login/en?client_id=3") #LOGIN URL

driver.find_element_by_id("email").send_keys("letrang.veo@gmail.com") #PUT YOUR EMAIL HERE
driver.find_element_by_id('login__password').send_keys('') #PUT YOUR PASSWORD HERE

driver.find_element_by_id("button-login").click()

driver.get("https://www.vietnamworks.com/it-software-jobs-i35-en") #THE WEB PAGE YOU NEED TO SCRAPE

time.sleep(5)
htmlSource = driver.page_source

soup= bs(htmlSource,"html.parser")
# Out:
# '<html><head><script type="text/javascript" async="" src="https://www.googleadservices.com/pagead/conversion_async.js"></script><script src="https://apis.google.com/_/scs/apps-static/_/js/k=oz.gapi.en_US.4sn9RO63fqo.O/m=plusone/rt=j/sv=1/d=1/ed=1/am=AQ/rs=AGLTcCO5GqPeHrbNQGs79bP09BnjVkdwag/cb=gapi.loaded_0?le=ili,ipu" async=""></script><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ga/inpage_linkid.js" id="undefined"></script><script src="https://connect.facebook.net/signals/config/379869466782000?v=2.9.44&amp;r=stable" async=""></script><script src="https://connect.facebook.net/signals/config/145665529509298?v=2.9.44&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-0GGBQ5L5MF&amp;l=dataLayer&amp
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

driver = webdriver.Chrome(executable_path=r'D:\Platform\chromedriver_win32\chromedriver.exe')#PUT YOUR CHROMEDRIVER PATH HERE

driver.get("https://itviec.com/sign_in") #LOGIN URL

driver.find_element_by_id("user_email").send_keys("letrang.veo@gmail.com") #PUT YOUR EMAIL HERE
driver.find_element_by_id('user_password').send_keys('') #PUT YOUR PASSWORD HERE

driver.switchTo().frame("a-9wt0e8vkopnm")
driver.findElement(By.xpath("//span[@id='recaptcha-anchor']")).click()

driver.get("https://itviec.com/") #THE WEB PAGE YOU NEED TO SCRAPE
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-cdae0efbb5cf> in <module>
#      10 driver.find_element_by_id('user_password').send_keys('letrang.veo@gmail.com') #PUT YOUR PASSWORD HERE
#      11
# ---> 12 driver.switchTo().frame("a-9wt0e8vkopnm")
#      13 driver.findElement(By.xpath("//span[@id='recaptcha-anchor']")).click()
#      14
#
# AttributeError: 'WebDriver' object has no attribute 'switchTo'

# %%
import requests

headers = {
    'authority': 'itviec.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"',
    'sec-ch-ua-mobile': '?0',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://itviec.com/sign_in',
    'accept-language': 'en-US,en;q=0.9,vi;q=0.8',
    'cookie': 'viewed_jobs=java-all-levels-success-software-services-4502; _gid=GA1.2.1189285654.1628743656; _gcl_au=1.1.488204289.1628743657; G_ENABLED_IDPS=google; recent_searches=; G_AUTHUSER_H=0; cvmissing=value; _gat=1; _dc_gtm_UA-42033311-2=1; _dc_gtm_UA-42033311-4=1; _ga_25PLWN9GB5=GS1.1.1628762311.4.1.1628762665.0; _ga=GA1.1.371346195.1628743656; remember_user_token=eyJfcmFpbHMiOnsibWVzc2FnZSI6Ilcxc3pPVEEzTWpSZExDSWtNbUVrTVRBa01VeE1RbGRNYTJWc1ZERnVSalYwVUdVME4zQnFkU0lzSWpFMk1qZzNOakkyTnprdU1qTTVPRFEySWwwPSIsImV4cCI6IjIwMjEtMDgtMjZUMTA6MDQ6MzkuMjM5WiIsInB1ciI6ImNvb2tpZS5yZW1lbWJlcl91c2VyX3Rva2VuIn19--d2c63fea6288589c3e836ffee2005ecb50b8be83; _ITViec_session=%2FoWd1kATA4%2FQg7XrRUwVX0FsMRVSwZ46CQSjYgdBWtq%2BvWdShPESLQfGFIZqfQKLZpPsOBpEY7ZM0QVAJbU9QlqxWCmLsMgIev5Dr6rKDUdr6Ibog6mHcFfHwI5VKpjWIlnlQ7ZC1aUwQUdgkwtPXQznLtrLXnveQQiGW%2BV66w%2FfLcqp6Pm33W48LRBXXxJlVsiES34T71wlHz8FrODcSCdNIB0HpYDxx44TgRSeZwNqjZjuII90Jh7qtj2vNzB2FiFDLsOPuawCTV8aUIstnbWd86hGyRozHLeV5BXrZvgCd08%2Bx3eCnZyX1qfpy2EpmcVeM%2B9WzJoaMe5X%2FQ2bXeWBDTmrn8l4IY5yEcxvWTEWXGV4DLyVg%2B%2F1YkIH6ChXye88QQA1BMkzNfE9XLRntq0Smq4usAZgSeBNSW7RGBtktXpqU3ykd8zX7TxWwA56DDi6douiWkcJcLIsoaPXZLhEAU1bz3j4SHpk9753EDxfO7rDn3pmgNC6CyvKyf%2FhcoI5Jv34U68kODwyvjxU--Qf%2FJu56Zg5MavOxP--yGAbqXpft5Q1kzWS%2BrUdXA%3D%3D',
}

response = requests.get('https://itviec.com/it-jobs', headers=headers)
data=response.text
soup=bs(data,"html.parser")
search=soup.findAll("div",{"class":"svg-icon__text"})
search
# Out:
# [<div class="svg-icon__text">Competitve</div>,
#  <div class="svg-icon__text">You'll love it</div>,
#  <div class="svg-icon__text">Competitive</div>,
#  <div class="svg-icon__text">You'll love it</div>,
#  <div class="svg-icon__text">You'll love it</div>,
#  <div class="svg-icon__text">1,200 - 2,000 USD</div>,
#  <div class="svg-icon__text">700 - 2,000 USD</div>,
#  <div class="svg-icon__text">You'll love it</div>,
#  <div class="svg-icon__text">You'll love it</div>,
#  <div class="svg-icon__text">1,300 - 1,900 USD</div>,
#  <div class="svg-icon__text">You'll love it</div>,
#  <div class="svg-icon__text">Attractive salary</div>,
#  <div class="svg-icon__text">1,000 - 1,500 USD</div>,
#  <div class="svg-icon__text">You'll love it</div>,
#  <div class="svg-icon__text">1,200 - 1,800 USD</div>,
#  <div class="svg-icon__text">1,000 - 1,800 USD</div>,
#  <div class="svg-icon__text">Thỏa thuận</div>,
#  <div class="svg-icon__text">$1,200 - $2,500 gross</div>,
# ...
