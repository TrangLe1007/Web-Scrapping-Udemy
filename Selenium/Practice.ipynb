# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import time
from PIL import Image
import io
import requests

from bs4 import BeautifulSoup as bs

# %%
#create the path of folder which coitans webdriver files
path="D:\Platform\chromedriver_win32\chromedriver.exe"
driver = webdriver.Chrome(path)

#open the website
url="https://itviec.com/blog"
driver.get(url)

#get the title of website
print(driver.title)

#quit the website
# driver.quit()
# driver.close()
# Out:
# ITviec Blog - Nơi Phát Triển Sự Nghiệp IT Của Bạn

# %%
pageSource= driver.page_source
driver.quit()
# print(pageSource)

#transfer page source into Beautifulsoup
soup =  bs(pageSource,"html.parser")
soup
# Out:
# <html lang="vi"><head><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-S6FMJYVBJ2&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="//www.googletagmanager.com/gtag/js?id=UA-42033311-3"></script><script>if(navigator.userAgent.match(/MSIE|Internet Explorer/i)||navigator.userAgent.match(/Trident\/7\..*?rv:11/i)){var href=document.location.href;if(!href.match(/[?&]nowprocket/)){if(href.indexOf("?")==-1){if(href.indexOf("#")==-1){document.location.href=href+"?nowprocket=1"}else{document.location.href=href.replace("#","?nowprocket=1#")}}else{if(href.indexOf("#")==-1){document.location.href=href+"&nowprocket=1"}else{document.location.href=href.replace("#","&nowprocket=1#")}}}}</script><script>class RocketLazyLoadScripts{constructor(e){this.triggerEvents=e,this.eventOptions={passive:!0},this.userEventListener=this.triggerListener.bind(this),thi
# ...

# %%
titles= soup.findAll("h1",{"class":"title large gradient-effect"})

for title in titles:
    print(title.text)
    # link=title.findAll("a")
    # print(link)
# Out:
# Low code là gì? Liệu Lập trình viên có bị mất việc vào “tay” Low-Code?
# Ngoài kỹ năng UI UX design, các designer non trẻ nên sở hữu 5 TỐ CHẤT này khi tìm việc
# Danh sách những công ty IT đã triển khai tiêm vaccine COVID 19 cho nhân viên (Cập nhật mới nhất)
# Những vị trí liên quan đến Machine Learning cơ bản đang có nhiều cơ hội trên thị trường
# Machine Learning là gì và Cách giải thích đúng mà dễ hiểu nhất
# Nhân viên IT cần thay đổi thế nào để thích nghi với môi trường làm việc “bình thường mới”?
# Những lý do vì sao con gái nên học Công nghệ Thông tin từ sớm
# Công ty phần mềm và Outsourcing nên làm gì để nhân viên làm việc năng suất nhất?
# Top 15 Công ty IT Tốt nhất Việt Nam 2021: Những chuyển biến tích cực
# Làm việc trái ngành: “Viên đạn bọc đường” hay “Cơ hội bất ngờ”?
